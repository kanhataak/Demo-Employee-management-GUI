# %%
from tkinter import *
import tkinter.messagebox
import sqlite3
from tabulate import tabulate

def insert(emp_no,emp_name,salary):
    conn=sqlite3.connect(r"C:\Users\MR.INDIA\Desktop\employee.db")
    cur=conn.cursor()
    cur.execute("INSERT INTO employee_table(emp_no,emp_name,salary)\
        VALUES(?,?,?)",(emp_no,emp_name,salary))
    conn.commit()
    conn.close()
    
    
def show():
    conn = sqlite3.connect(r"C:\Users\MR.INDIA\Desktop\employee.db")
    cur = conn.cursor()
    cur.execute('SELECT * FROM employee_table')
    row = cur.fetchall()
    conn.close()
    return row


def search(emp_name):
    conn = sqlite3.connect(r"C:\Users\MR.INDIA\Desktop\employee.db")
    cur = conn.cursor()
    cur.execute("SELECT * FROM employee_table WHERE emp_name=?",(emp_name))
    row = cur.fetchall()
    conn.close()
    return rows
                           
def delete(emp_name):
    conn=sqlite3.connect(r"C:\Users\MR.INDIA\Desktop\employee.db")
    cur = conn.cursor()
    cur.execute('DELETE FROM employee_table WHERE emp_name = ?',(emp_name,))
    conn.commit()
    conn.close()
                           
                                                
def update(emp_id,emp_name,salary):  
    emp_id=int(emp_id)
    salary=int(salary)
#     print(type(emp_id),type(emp_name),type(salary))
    conn=sqlite3.connect(r"C:\Users\MR.INDIA\Desktop\employee.db")
    cur = conn.cursor()
    cur.execute('UPDATE employee_table SET emp_name=?,salary=? where emp_no=?',(emp_name,salary,emp_id))
    conn.commit()
    conn.close()
 
#--------------- fix digit len in phone number entry --------------------
def validate_input(new_value):
    valid=new_value.isdigit() and len(new_value) <=10
    return valid
    
# -----------------Add employee ----------------------------
def add_emp():
    top= Toplevel()
    top.title("Add_Employee")
    top.geometry('600x400')
    
    validate=top.register(validate_input)
    
    Label(top, text= "Add Employee",font= "Times 30").grid(row=2, columnspan= 3, padx=70,pady=10)
    
    Label(top, text= "Emp_No:",font= "Times 15").grid(row=3, column= 0, sticky= W, padx= 40,pady= 5)
    Label(top, text= "Emp_Name:",font= "Times 15").grid(row=4, column= 0, sticky= W, padx= 40,pady= 5)
    Label(top, text= "Salary:",font= "Times 15").grid(row=5, column= 0, sticky= W, padx= 40,pady= 5)
    
    e1= Entry(top,bd=3,font=1)
    e1.grid(row=3,column=1,pady=10,sticky=W)
    e2= Entry(top,bd=4,font=1)
    e2.grid(row=4,column=1,pady=10,sticky=W)
    e3= Entry(top,bd=5,font=1,validate="key",validatecommand=(validate,"%P"))
    e3.grid(row=5,column=1,pady=10,sticky=W)
    
    def add():
        emp_no=e1.get()
        name=e2.get()
        salary=e3.get()
        insert(emp_no,name,salary)
        
    
    
    Button(top,bd=5,text='Add Emp.',font=10,width=8,\
           bg="#39FD03", fg="white",command=add).grid(row=6,column=1,sticky=W,pady=15)
    Button(top,bd=5,text='Go Back',command = top.destroy,font=10,width=8,\
           bg="#FC0606", fg="white").grid(row=6,column=1,sticky=E)

# ========================= search employee ================================= 
def search_emp():
    top= Toplevel()
    top.title("Search_Employee")
    top.geometry('600x425')
    
    Label(top, text= "Search Employee",font= "Times 30").grid(row=2, columnspan= 3, padx=70,pady=10)
    Label(top, text= "Emp_Name:",font= "Times 15").grid(row=3, column= 0, sticky= W, padx= 40,pady= 5)
    
    e1= Entry(top,bd=3,font=1)
    e1.grid(row=3,column=1,pady=10,sticky=W)
    def sech():
        emp_name=e1.get()
        u = search(emp_name)
    
    
    
    Button(top,bd=5,text='Search',font=10,width=8,\
           bg="#39FD03", fg="white",command = sech).grid(row=6,column=1,sticky=W,pady=10)
    Button(top,bd=5,text='Go Back',command = top.destroy,font=10,width=8,\
           bg="#FC0606", fg="white").grid(row=6,column=1,sticky=E)
    


    for row in u:
        mlb.insert('end',*map(unicode,row))
        root.mainloop()
    
    listbox = Listbox(top,height=10,width=55)
    listbox.grid(row=7, columnspan=2,sticky= E,pady= 10)


# ------------------------------ show all employee -----------------------------   

def show_emp():
    top= Toplevel()
    top.title("Show_Employee")
    top.geometry('600x425') 
    Label(top, text= "Show All Employee",font= "Times 30").pack(side= TOP, expand= True)#grid(row=2, columnspan= 3, padx=70,pady=10)
    
    listbox = Text(top,height=10,width=55)
    listbox.pack(side=TOP, expand= True)
    data=show()
#     print(tabulate(data,tablefmt="fancy_grid"))
    listbox.insert(END,tabulate(data,tablefmt="fancy_grid"))
    Button(top,bd=5,text='Go Back',command = top.destroy,font=10,width=8,\
           bg="#FC0606", fg="white").pack(side=TOP, expand=True)#grid(row=4,column=1,pady=15)


# -------------------------------update employee ----------------------------
def update_emp():
    top= Toplevel()
    top.geometry('600x425')
    top.title("Update_Emaployee")
    Label(top, text= "Update Employee",).grid(row=2, columnspan= 3, padx=70,pady=10)

    Label(top,text= "Emp_ID:",font= "Times 15").grid(row=3, column= 0,sticky= W, padx = 45)
    Label(top, text= "Emp_Name:", font="Times 15").grid(row=4, column= 0,sticky= W, padx = 45)
    Label(top, text= "Salary:", font="Times 15").grid(row=5, column= 0,sticky= W, padx = 45)
    
    e1= Entry(top,bd=3,font=1)
    e1.grid(row=3,column=1,pady=10,sticky=W)
    e2= Entry(top,bd=3,font=1)
    e2.grid(row=4,column=1,pady=10,sticky=W)
    e3= Entry(top,bd=3,font=1)
    e3.grid(row=5,column=1,pady=10,sticky=W)
    def update_data():
        emp_id=e1.get()
        emp_name=e2.get()
        salary=e3.get()
        update(emp_id,emp_name,salary)
    Button(top,bd=5,text='Update',font=7,width=8,\
           bg="#39FD03", fg="white",command=update_data).grid(row=6,column=1,sticky=W,pady=20)
    Button(top,bd=5,text='Go Back',command = top.destroy,font=10,width=8,\
           bg="#FC0606", fg="white").grid(row=6,column=1,sticky=E)
    
#-----------------------------Delete employee ----------------------------

def delete_emp():
    top= Toplevel()
    top.geometry('600x425')
    top.title("Delete_Emaployee") 
    Label(top, text= "Delete Employee",font= "Times 30").grid(row=2, columnspan= 3, padx=70,pady=10)
    Label(top, text= "Employee Name", font= "Times 15").grid(row=3, column= 0, padx=40,pady= 10)

    e1= Entry(top,bd=3,font=1)
    e1.grid(row=3,column=1,pady=10,sticky=W)
    
    def del_data():
        emp_name=e1.get()
        delete(emp_name)
        
    Button(top,bd=5,text='Remove',font=10,width=8,\
           bg="#39FD03", fg="white",command=del_data).grid(row=4,column=1,sticky=W,pady=10)
    Button(top,bd=5,text='Go Back',command = top.destroy,font=10,width=8,\
           bg="#FC0606", fg="white").grid(row=4,column=1,sticky=E)
    
    
    
    add=Text(top,font='Times 15',bg='#F6F8EE',bd=3,height=4,width=22)
    add.grid(row=5,column=1,ipady=20)   

#--------------------------- Main window Buttons --------------------------------


root= Tk()
root.title("Employee Management")
Label(root, text="Select Your Choice",font="Times 30").pack(side = TOP, expand = True)
           
button1= Button(root,text="Add Employee",bd=5,font='Times 15',width=25,bg="#39FD03", fg="white",command= add_emp)
button1.pack()
button2= Button(root,text="Search Employee",bd=5,font='Times 15',width=25,bg="#39FD03", fg="white",command= search_emp)
button2.pack()
button3= Button(root,text="Show All Employee",bd=5,font='Times 15',width=25,bg="#39FD03", fg="white",command= show_emp)
button3.pack()
button4= Button(root,text="Update Employee",bd=5,font='Times 15',width=25,bg="#39FD03", fg="white",command= update_emp)
button4.pack()
button5= Button(root,text="Delete Employee",bd=5,font='Times 15',width=25,bg="#39FD03", fg="white",command= delete_emp)
button5.pack()
def exit():
    exit = tkinter.messagebox.askokcancel("Employee Management System","Confirm if you want to exit.",icon="warning")
    if exit ==True:
        root.destroy()
        return
button6= Button(root,text="Quit",bd=5,font='Times 15',width=25,bg="#FC0606", fg="white",command = exit)
button6.pack(side = TOP, expand = True)

root.geometry("600x700")
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\python37\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-8a9511443734>", line 113, in search_emp
#     for row in u:
# NameError: name 'u' is not defined
